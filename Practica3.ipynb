# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoPaiz8/IA_IB_DiegoPaiz/blob/main/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar las dos imágenes
imagen2 = cv2.imread("/content/costillas.jpg", cv2.IMREAD_GRAYSCALE)
imagen1 = cv2.imread("/content/cervicales.jpeg", cv2.IMREAD_GRAYSCALE)

# Redimensionar ambas imágenes al mismo tamaño
imagen2_res = cv2.resize(imagen2, (imagen1.shape[1], imagen1.shape[0]))

# Aplicar la suma ponderada con pesos α=0.8 y β=0.5
alpha = 0.8  # Peso de la primera imagen
beta = 0.5   # Peso de la segunda imagen
gamma = 10     # Ajuste de brillo

imagen_resultado = cv2.addWeighted(imagen1, alpha, imagen2_res, beta, gamma)

# Mostrar imágenes
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.imshow(imagen1, cmap="gray")
plt.title("Imagen 1")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(imagen2, cmap="gray")
plt.title("Imagen 2")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(imagen_resultado, cmap="gray")
plt.title("Suma Ponderada")
plt.axis("off")

plt.show()

# %%
# Cargar varias imágenes en una lista
# Imagenes descargadas de: https://www.kaggle.com/datasets/tawsifurrahman/covid19-radiography-database/data
imagenes = ["/content/costillas.jpg", "/content/cervicales.jpeg"]
imagenes_cargadas = [cv2.imread(img, cv2.IMREAD_GRAYSCALE) for img in imagenes]


# Verificar que todas las imágenes tengan el mismo tamaño
alto, ancho = imagenes_cargadas[0].shape
imagenes_cargadas = [cv2.resize(img, (ancho, alto)) for img in imagenes_cargadas]

# Crear una imagen acumuladora en formato flotante
suma = np.zeros((alto, ancho), dtype=np.float32)

# Sumar todas las imágenes
for img in imagenes_cargadas:
    suma += img

# Calcular el promedio dividiendo por la cantidad de imágenes
imagen_promedio = suma / len(imagenes_cargadas)

# Convertir la imagen a formato uint8 para visualización
"""
En OpenCV, las imágenes se almacenan generalmente en formato
uint8 (valores de píxeles entre 0 y 255). Sin embargo, cuando
realizamos operaciones matemáticas como la suma promedio de
imágenes, los valores pueden volverse flotantes o salir del
rango válido.
"""
imagen_promedio = cv2.convertScaleAbs(imagen_promedio)

# Mostrar imágenes originales
for i, img in enumerate(imagenes_cargadas):
    plt.subplot(1, len(imagenes), i+1)  # Crear subgráficos en una fila
    #plt.figure(figsize=(10, 5))
    plt.imshow(img, cmap="gray")  # Mostrar imagen
    plt.title(f"Imagen {i+1}")  # Título de cada imagen
    plt.axis("off")  # Ocultar ejes

plt.show()

#Mostrar imagen promedio
plt.figure(figsize=(5, 5))
#plt.subplot(1, 3, 1)
plt.imshow(imagen_promedio, cmap="gray")
plt.title("Promedio")
plt.axis("off")
plt.show()

# %%
# Cargar las dos imágenes
img1 = cv2.imread("/content/cervicales.jpeg", cv2.IMREAD_GRAYSCALE)  # Cargar en escala de grises
img2 = cv2.imread("/content/costillas.jpg", cv2.IMREAD_GRAYSCALE)

# Asegurar que tengan el mismo tamaño
img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

# Realizar la resta de imágenes
resta = cv2.subtract(img2, img1)  # OpenCV maneja el rango automáticamente

# Mostrar imágenes originales y resultado
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(img1, cmap='gray')
plt.title("Imagen 1")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(img2, cmap='gray')
plt.title("Imagen 2")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(resta, cmap='gray')
plt.title("Resta")
plt.axis("off")

plt.show()

# %%
# Cargar imagen en escala de grises
img = cv2.imread("/content/costillas.jpg", cv2.IMREAD_GRAYSCALE)

# Definir el factor de multiplicación
factor1 = 1.8

# Multiplicar la imagen por el factor
img_multiplicada1 = cv2.multiply(img, np.array([factor1], dtype=np.float32))

# Convertir la imagen a uint8 para visualización correcta
img_multiplicada1 = cv2.convertScaleAbs(img_multiplicada1)

# Definir el factor de multiplicación
factor2 = 0.8

# Multiplicar la imagen por el factor
img_multiplicada2 = cv2.multiply(img, np.array([factor2], dtype=np.float32))

# Convertir la imagen a uint8 para visualización correcta
img_multiplicada2 = cv2.convertScaleAbs(img_multiplicada2)

# Definir el factor de multiplicación
factor3 = 1.2

# Multiplicar la imagen por el factor
img_multiplicada3 = cv2.multiply(img, np.array([factor3], dtype=np.float32))

# Convertir la imagen a uint8 para visualización correcta
img_multiplicada3 = cv2.convertScaleAbs(img_multiplicada3)

# Mostrar la imagen original y la modificada
plt.figure(figsize=(10, 4))

plt.subplot(1, 4, 1)
plt.imshow(img, cmap='gray')
plt.title("Imagen Original")
plt.axis("off")

plt.subplot(1, 4, 2)
plt.imshow(img_multiplicada1, cmap='gray')
plt.title(f"Imagen x {factor1}")
plt.axis("off")

plt.subplot(1, 4, 3)
plt.imshow(img_multiplicada2, cmap='gray')
plt.title(f"Imagen x {factor2}")
plt.axis("off")
plt.show()

plt.subplot(1, 4, 4)
plt.imshow(img_multiplicada3, cmap='gray')
plt.title(f"Imagen x {factor3}")
plt.axis("off")
plt.show()

# %%
# Cargar imagen en escala de grises
img = cv2.imread("/content/cervicales.jpeg", cv2.IMREAD_GRAYSCALE)

# Definir el factor de multiplicación
factor1 = 1.8

# Multiplicar la imagen por el factor
img_multiplicada1 = cv2.multiply(img, np.array([factor1], dtype=np.float32))

# Convertir la imagen a uint8 para visualización correcta
img_multiplicada1 = cv2.convertScaleAbs(img_multiplicada1)

# Definir el factor de multiplicación
factor2 = 0.8

# Multiplicar la imagen por el factor
img_multiplicada2 = cv2.multiply(img, np.array([factor2], dtype=np.float32))

# Convertir la imagen a uint8 para visualización correcta
img_multiplicada2 = cv2.convertScaleAbs(img_multiplicada2)

# Definir el factor de multiplicación
factor3 = 1.2

# Multiplicar la imagen por el factor
img_multiplicada3 = cv2.multiply(img, np.array([factor3], dtype=np.float32))

# Convertir la imagen a uint8 para visualización correcta
img_multiplicada3 = cv2.convertScaleAbs(img_multiplicada3)

# Mostrar la imagen original y la modificada
plt.figure(figsize=(10, 4))

plt.subplot(1, 4, 1)
plt.imshow(img, cmap='gray')
plt.title("Imagen Original")
plt.axis("off")

plt.subplot(1, 4, 2)
plt.imshow(img_multiplicada1, cmap='gray')
plt.title(f"Imagen x {factor1}")
plt.axis("off")

plt.subplot(1, 4, 3)
plt.imshow(img_multiplicada2, cmap='gray')
plt.title(f"Imagen x {factor2}")
plt.axis("off")
plt.show()

plt.subplot(1, 4, 4)
plt.imshow(img_multiplicada3, cmap='gray')
plt.title(f"Imagen x {factor3}")
plt.axis("off")
plt.show()

# %%
# Cargar las dos imágenes en escala de grises
img1 = cv2.imread("/content/cervicales.jpeg", cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread("/content/costillas.jpg", cv2.IMREAD_GRAYSCALE)

# Redimensionar para que tengan el mismo tamaño
img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

# Multiplicación elemento a elemento
img_multiplicada = cv2.multiply(img2, img1)  # OpenCV maneja el rango automáticamente

# Convertir la imagen resultante a uint8
img_multiplicada = cv2.convertScaleAbs(img_multiplicada)

# Mostrar imágenes originales y resultado
plt.figure(figsize=(8, 4))

plt.subplot(1, 3, 1)
plt.imshow(img1, cmap='gray')
plt.title("Imagen 1")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(img2, cmap='gray')
plt.title("Imagen 2")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(img_multiplicada, cmap='gray')
plt.title("Multiplicación Elemento a Elemento")
plt.axis("off")

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar las imágenes en escala de grises
img1 = cv2.imread('costillas.jpg', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('cervicales.jpeg', cv2.IMREAD_GRAYSCALE)

# Imágenes al mismo tamaño
height, width = 300, 300  # Tamaño estándar para comparación
img1 = cv2.resize(img1, (width, height))
img2 = cv2.resize(img2, (width, height))

# Convertir las imágenes a binarias
_, binary1 = cv2.threshold(img1, 127, 255, cv2.THRESH_BINARY)
_, binary2 = cv2.threshold(img2, 127, 255, cv2.THRESH_BINARY)

# Aplicar operaciones lógicas
and_img = cv2.bitwise_and(binary1, binary2)
or_img = cv2.bitwise_or(binary1, binary2)
not_img1 = cv2.bitwise_not(binary1)
xor_img = cv2.bitwise_xor(binary1, binary2)

# Mostrar las imágenes
titles = ["Costillas", "Cervicales", "AND", "OR", "NOT (Cerebro)", "XOR"]
images = [binary1, binary2, and_img, or_img, not_img1, xor_img]

plt.figure(figsize=(12, 6))

for i in range(6):
    plt.subplot(2, 3, i + 1)
    plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.axis("off")

plt.tight_layout()
plt.show()
